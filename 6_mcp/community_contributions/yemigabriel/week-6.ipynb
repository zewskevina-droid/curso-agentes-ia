# %% [markdown]
# ### Travel Planner
#
# A travel planner workflow using MCP. It helps with planning your itinerary, searching for and booking hotels It comprises:
# - External research MCP servers so the `TravelResearcher` can use Brave Search and Playwright browser tools.
# - A Gradio chat interface for starting prompts and confirmation before browser-assisted booking continues.

# %%
# import sys
# from pathlib import Path

# ROOT = Path.cwd()
# for candidate in [ROOT, *ROOT.parents]:
#     if (candidate / '6_mcp' / 'travel_web_app.py').exists():
#         sys.path.insert(0, str(candidate / '6_mcp'))
#         break

# %%
from travel_web_app import create_travel_ui

# %% [markdown]
# Use the chat UI for both steps:
# - Start with a free-form travel request.
# - Review the proposed plan.
# - Click `Confirm Browsing` only when you want the Playwright-backed browser workflow to continue.

# %%
travel_ui = create_travel_ui()
travel_ui.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# Suggested prompt:
#
# `Plan a 3-day Lagos birthday staycation with a quiet hotel, art spots, good food, and a moderate budget.`

# %%
# Optional: launch the UI in a new browser tab instead of rendering inline.
# travel_ui.launch(inbrowser=True)

# %%
# Safety note: the browser workflow is instructed to stop before any irreversible
# confirmation or payment step on a live booking site.
