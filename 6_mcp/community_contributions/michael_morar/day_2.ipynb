# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents.mcp import MCPServerStdio
from IPython.display import display, Markdown

load_dotenv(override=True)
# Out:
# True

# %%
params = {"command": "uv", "args": ["run", "date_server.py"]}
async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()

# %%
mcp_tools
# Out:
# [Tool(name='get_date', title=None, description='Get the current date and time.\n\n    Args:\n        None\n    ', inputSchema={'properties': {}, 'title': 'get_dateArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'title': 'Result', 'type': 'string'}}, 'required': ['result'], 'title': 'get_dateOutput', 'type': 'object'}, icons=None, annotations=None, meta=None)]

# %%
instructions = "You are able to retrieve the current date and time"
request = "What exactly is the current date and time?"
model = "gpt-4.1-mini"

# %%
async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as mcp_server:
    agent = Agent(name="date_fetcher", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("date_fetcher"):
        result = await Runner.run(agent, request)
    display(Markdown(result.final_output))
# Out:
# The current date and time is April 18, 2026, 18:33 (6:33 PM).

# %%
instructions2 = "you are able to write songs in B Minor and generate tablature for electric bass"
request2="write me a song and give me the bass tabs"
params2 = {"command": "uv", "args": ["run", "another_server.py"]}

async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as mcp_server:
    agent = Agent(name="another_fetcher", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("another_fetcher"):
        result = await Runner.run(agent, request2)
    display(Markdown(result.final_output))
# Out:
# Error initializing MCP server: Connection closed
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       2 request2="write me a song and give me the bass tabs"
#       3 params2 = {"command": "uv", "args": ["run", "another_server.py"]}
# ----> 5 async with MCPServerStdio(params=params2, client_session_timeout_seconds=30) as mcp_server:
#       6     agent = Agent(name="another_fetcher", instructions=instructions, model=model, mcp_servers=[mcp_server])
#       7     with trace("another_fetcher"):
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:237, in _MCPServerWithClientSession.__aenter__(self)
#     236 async def __aenter__(self):
# --> 237     await self.connect()
#     238     return self
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/agents/mcp/server.py:277, in _MCPServerWithClientSession.connect(self)
#     266 read, write, *_ = transport
#     268 session = await self.exit_stack.enter_async_context(
#     269     ClientSession(
#     270         read,
#    (...)    275     )
#     276 )
# --> 277 server_result = await session.initialize()
#     278 self.server_initialize_result = server_result
#     279 self.session = session
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/mcp/client/session.py:151, in ClientSession.initialize(self)
#     139 elicitation = (
#     140     types.ElicitationCapability() if self._elicitation_callback is not _default_elicitation_callback else None
#     141 )
#     142 roots = (
#     143     # TODO: Should this be based on whether we
#     144     # _will_ send notifications, or only whether
#    (...)    148     else None
#     149 )
# --> 151 result = await self.send_request(
#     152     types.ClientRequest(
#     153         types.InitializeRequest(
#     154             params=types.InitializeRequestParams(
#     155                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     156                 capabilities=types.ClientCapabilities(
#     157                     sampling=sampling,
#     158                     elicitation=elicitation,
#     159                     experimental=None,
#     160                     roots=roots,
#     161                 ),
#     162                 clientInfo=self._client_info,
#     163             ),
#     164         )
#     165     ),
#     166     types.InitializeResult,
#     167 )
#     169 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     170     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/mcp/shared/session.py:286, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     274     raise McpError(
#     275         ErrorData(
#     276             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    282         )
#     283     )
#     285 if isinstance(response_or_error, JSONRPCError):
# --> 286     raise McpError(response_or_error.error)
#     287 else:
#     288     return result_type.model_validate(response_or_error.result)
#
# McpError: Connection closed
